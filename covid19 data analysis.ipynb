# %%
#import necessary modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#open covid19 file
covid_confirmed_data=pd.read_csv('data_analysis/covid19.csv')
covid_confirmed_data.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/16/20  7/17/20  7/18/20  \
# 0        0        0        0        0  ...    35070    35229    35301
# 1        0        0        0        0  ...     3851     3906     4008
# 2        0        0        0        0  ...    21355    21948    22549
# 3        0        0        0        0  ...      877      880      880
# 4        0        0        0        0  ...      607      638      687
#
#    7/19/20  7/20/20  7/21/20  7/22/20  7/23/20  7/24/20  7/25/20
# ...

# %%
#drop unnecessary columns
covid_confirmed_data.drop(["Lat","Long"],axis=1,inplace=True)
covid_confirmed_data
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN  Sao Tome and Principe        0        0        0        0
# 262            NaN                  Yemen        0        0        0        0
# 263            NaN                Comoros        0        0        0        0
# 264            NaN             Tajikistan        0        0        0        0
# 265            NaN                Lesotho        0        0        0        0
#
# ...

# %%
#sum the values and use groupby to put duplicates together into one
covid_data=covid_confirmed_data.groupby("Country/Region").sum()
covid_data
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
covid_china=covid_data.loc['China'].plot()
# Out:
# c:\program files (x86)\python\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
covid_data.loc['China'].head(3).plot()
#Notice increase in cases in a 24 hour period
#day1=100(650-550)
# Out:
# c:\program files (x86)\python\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:>

# %%
#compare any 3 countries
covid_data.loc['China'].plot()
covid_data.loc['Italy'].plot()
covid_data.loc['Spain'].plot()
plt.legend()
# Out:
# c:\program files (x86)\python\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
#calculate first derivative
covid_data.loc['China'].diff().plot()
# Out:
# c:\program files (x86)\python\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:>

# %%
#find maximum
covid_data.loc['China'].diff().max()
# Out:
# 15136.0

# %%
#find max for all countries and store it in separate column
countries=list(covid_data.index)
#countries
max_infection_rate=[]
for country in countries:
    max_infection_rate.append(covid_data.loc[country].diff().max())
#max_infection_rate
covid_data['max_infection_rate']=max_infection_rate
covid_data
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
#keep necessary columns and remove the rest
covid_final_data=pd.DataFrame(covid_data["max_infection_rate"])
covid_final_data
# Out:
#                     max_infection_rate
# Country/Region
# Afghanistan                      915.0
# Albania                          119.0
# Algeria                          675.0
# Andorra                           79.0
# Angola                            62.0
# ...                                ...
# West Bank and Gaza               501.0
# Western Sahara                     4.0
# Yemen                            116.0
# Zambia                           915.0
# Zimbabwe                         273.0
#
# [188 rows x 1 columns]

# %%
#covid_final_data.plot()
#import world_happiness_report file
happiness_report=pd.read_csv('data_analysis/world_happiness_report.csv')
happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#keep only necessary columns
happiness_report.drop(['Overall rank','Score','Generosity','Perceptions of corruption'],axis=1,inplace=True)
happiness_report
# Out:
#             Country or region  GDP per capita  Social support  \
# 0                     Finland           1.340           1.587
# 1                     Denmark           1.383           1.573
# 2                      Norway           1.488           1.582
# 3                     Iceland           1.380           1.624
# 4                 Netherlands           1.396           1.522
# ..                        ...             ...             ...
# 151                    Rwanda           0.359           0.711
# 152                  Tanzania           0.476           0.885
# 153               Afghanistan           0.350           0.517
# 154  Central African Republic           0.026           0.000
# 155               South Sudan           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices
# 0                      0.986                         0.596
# 1                      0.996                         0.592
# ...

# %%
#reset_index to make it easier for merging two files
happiness_report.set_index('Country or region')
happiness_report.reset_index()
happiness_report.rename(columns={'Country or region':'Country/Region'},inplace=True)
happiness_report=happiness_report.set_index('Country/Region')
happiness_report
# Out:
#                           GDP per capita  Social support  \
# Country/Region
# Finland                            1.340           1.587
# Denmark                            1.383           1.573
# Norway                             1.488           1.582
# Iceland                            1.380           1.624
# Netherlands                        1.396           1.522
# ...                                  ...             ...
# Rwanda                             0.359           0.711
# Tanzania                           0.476           0.885
# Afghanistan                        0.350           0.517
# Central African Republic           0.026           0.000
# South Sudan                        0.306           0.575
#
#                           Healthy life expectancy  \
# Country/Region
# Finland                                     0.986
# Denmark                                     0.996
# Norway                                      1.028
# ...

# %%
covid_final_data.shape
# Out:
# (188, 1)

# %%
happiness_report.shape
# Out:
# (156, 4)

# %%
#merge the files 
data=covid_final_data.join(happiness_report,how='inner')#since the files are of diff. shapes,use inner join
data
# Out:
#                 max_infection_rate  GDP per capita  Social support  \
# Country/Region
# Afghanistan                  915.0           0.350           0.517
# Albania                      119.0           0.947           0.848
# Algeria                      675.0           1.002           1.160
# Argentina                   6127.0           1.092           1.432
# Armenia                      771.0           0.850           1.055
# ...                            ...             ...             ...
# Venezuela                    666.0           0.960           1.427
# Vietnam                       24.0           0.741           1.346
# Yemen                        116.0           0.287           1.163
# Zambia                       915.0           0.578           1.058
# Zimbabwe                     273.0           0.366           1.114
#
#                 Healthy life expectancy  Freedom to make life choices
# Country/Region
# ...

# %%
data.corr()
#positive correlation indicates that the variables move in the same direction
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.121209
# GDP per capita                          0.121209        1.000000
# Social support                          0.095747        0.757521
# Healthy life expectancy                 0.109645        0.859431
# Freedom to make life choices            0.069591        0.394799
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.095747                 0.109645
# GDP per capita                      0.757521                 0.859431
# Social support                      1.000000                 0.751632
# Healthy life expectancy             0.751632                 1.000000
# Freedom to make life choices        0.456317                 0.423146
#
#                               Freedom to make life choices
# max_infection_rate                                0.069591
# ...

# %%
#plot comparison graphs
y=data['max_infection_rate']
x=data['GDP per capita']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
#regression line
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
y=data['max_infection_rate']
x=data['Social support']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Social support', ylabel='max_infection_rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Social support', ylabel='max_infection_rate'>

# %%
y=data['max_infection_rate']
x=data['Healthy life expectancy']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_infection_rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_infection_rate'>

# %%
y=data['max_infection_rate']
x=data['Freedom to make life choices']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_infection_rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_infection_rate'>

# %%
data.head(5).plot()
# Out:
# c:\program files (x86)\python\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Country/Region'>
